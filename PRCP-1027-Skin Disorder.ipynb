# %% [markdown]
# # <center><font color="red">PRCP-1027-Skin Disorder</center>

# %% [markdown]
# ## PROBLEM STATEMENT

# %% [markdown]
# #### --> Potential reasons and contributing factors for skin disorders are Inflammatory Responses,Keratinization and Epidermal Abnormalities,Immune-Mediated and Autoimmune Factors & other factors.
# #### --> This project analyzes skin disorder data to identify key patterns and trends in skin disorder cases. A predictive model will be developed using various machine learning classifiers to classify patients accurately by type of skin disorder.
# #### --> Additionally, an in-depth analysis will be conducted to justify the choice of models, highlighting the most influential factors contributing to skin disorder. This study seeks to provide data-driven insights that can assist healthcare professionals in early diagnosis and effective intervention strategies.

# %% [markdown]
# ## DOMAIN ANALYSIS AND ATTRIBUTES

# %% [markdown]
# #### This project falls under "Healthcare" domain to classify patients accurately by type of skin disorder based on the key attributes such as,
# #### Clinical Attributes:
# #### --> Erythema: Redness of the skin, often due to inflammation. It is a common symptom in many skin diseases, including psoriasis and eczema.
# #### --> Scaling: The shedding of the outer layer of the skin, often seen in conditions like psoriasis and ichthyosis.
# #### --> Definite Borders: Clearly defined edges of skin lesions, which can help differentiate between diseases like psoriasis (well-defined borders) and eczema (less defined).
# #### --> Itching: Pruritus, a common symptom in conditions such as eczema and lichen planus.
# #### --> Koebner Phenomenon: The appearance of skin lesions at the site of trauma, seen in conditions like psoriasis and lichen planus.
# #### --> Polygonal Papules: Small, raised bumps with flat tops, often seen in lichen planus.
# #### --> Follicular Papules: Bumps centered around hair follicles, commonly associated with conditions like follicular eczema or keratosis pilaris.
# #### --> Oral Mucosal Involvement: Involvement of the mucous membranes inside the mouth, seen in conditions like lichen planus.
# #### --> Knee and Elbow Involvement: Common sites for psoriasis lesions.
# #### --> Scalp Involvement: Involvement of the scalp, common in conditions like psoriasis and seborrheic dermatitis.
# #### --> Family History: Presence of similar skin conditions in family members, relevant for conditions like psoriasis.
#
# #### Histopathological Attributes:
# #### --> Melanin Incontinence: Disruption of melanin pigment into the dermis, often seen in conditions causing inflammation or trauma.
# #### --> Eosinophils in the Infiltrate: Presence of eosinophils, a type of white blood cell, indicating allergic reactions or parasitic infections.
# #### --> PNL Infiltrate: Presence of polymorphonuclear leukocytes (PMNs), indicating acute inflammation.
# #### --> Fibrosis of the Papillary Dermis: Scarring in the upper dermis, often seen in chronic conditions like lichen planus.
# #### --> Exocytosis: Movement of cells into the epidermis from the dermis, seen in conditions like eczema.
# #### --> Acanthosis: Thickening of the epidermis, common in conditions like psoriasis.
# #### --> Hyperkeratosis: Thickening of the stratum corneum, often seen in conditions like ichthyosis.
# #### --> Parakeratosis: Presence of nuclei in the stratum corneum, indicating abnormal maturation of skin cells.
# #### --> Clubbing of the Rete Ridges: Distortion of the rete ridges, seen in conditions like psoriasis.
# #### --> Elongation of the Rete Ridges: Lengthening of the rete ridges, often seen in conditions like psoriasis.
# #### --> Thinning of the Suprapapillary Epidermis: Reduction in thickness of the epidermis above the dermal papillae, seen in conditions like psoriasis.
# #### --> Spongiform Pustule: A type of pustule seen in conditions like pustular psoriasis.
# #### --> Munro Microabscess: Collections of neutrophils in the stratum corneum, characteristic of psoriasis.
# #### --> Focal Hypergranulosis: Increased thickness of the granular layer in certain areas, seen in conditions like psoriasis.
# #### --> Disappearance of the Granular Layer: Loss of the granular layer, often seen in conditions like psoriasis.
# #### --> Vacuolisation and Damage of Basal Layer: Damage to the basal layer of the epidermis, seen in conditions like lichen planus.
# #### --> Spongiosis: Edema within the epidermis, often seen in conditions like eczema.
# #### --> Saw-Tooth Appearance of Rete Ridges: Distortion of the rete ridges, characteristic of psoriasis.
# #### --> Follicular Horn Plug: A plug of keratin within a hair follicle, seen in conditions like keratosis pilaris.
# #### --> Perifollicular Parakeratosis: Presence of parakeratotic cells around hair follicles, seen in conditions like seborrheic dermatitis.
# #### --> Inflammatory Mononuclear Infiltrate: Presence of mononuclear cells (like lymphocytes and macrophages) indicating chronic inflammation.
# #### --> Band-Like Infiltrate: A dense band of inflammatory cells at the dermo-epidermal junction, characteristic of lichen planus.
# #### --> Age: A linear attribute indicating the patient's age, which can influence the likelihood of certain skin conditions.
#
# #### Target attribute:
# #### --> Class: Patients with various types of skin disorders(1:psoriasis, 2:seboreic dermatitis, 3:lichen planus, 4:pityriasis rosea, 5:cronic dermatitis and 6:pityriasis rubra pilaris).

# %% [markdown]
# ## 1. IMPORTING LIBRARIES

# %%
# Importing pandas library for working with data sets
import pandas as pd

# Importing numpy library for working with arrays
import numpy as np

# Importing matplotlib.pyplot for visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# Importing seaborn library for advanced visualization
import seaborn as sns

# Importing warnings for disable warnings from the code
import warnings
# To ignore the warnings
warnings.filterwarnings('ignore')

# YData Profiling for generating an automatic exploratory data analysis (EDA) report
from ydata_profiling import ProfileReport

# Importing train_test_split for splitting data into training and testing sets for model evaluation
from sklearn.model_selection import train_test_split

# Importing LogisticRegression
from sklearn.linear_model import LogisticRegression

# Importing DecisionTreeClassifier 
from sklearn.tree import DecisionTreeClassifier

# Importing an ensemble model RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# Importing an advanced boosting model GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier 

# Importing SVC model from sklearn
from sklearn.svm import SVC

# Importing KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier

# Importing GridSearchCV for Hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# Importing RandomizedSearchCV for hyperparameter tuning using randomized search
from sklearn.model_selection import RandomizedSearchCV

# Importing Multi-layer Perceptron (MLP) Classifier
from sklearn.neural_network import MLPClassifier

# Importing performance metrics for model evaluation
# accuracy_score,confusion_matrix,classification_report,etc.
from sklearn.metrics import *

# %% [markdown]
# ## 2. LOADING THE DATA

# %%
data = pd.read_csv('dermatology.csv')
data
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %% [markdown]
# ## 3. BASIC CHECKS

# %%
# Visualizing the first 10 rows of the data
data.head(10)
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
# 5         2        3                 2        0                   0
# 6         2        1                 0        2                   0
# 7         2        2                 3        3                   3
# 8         2        2                 1        0                   2
# 9         2        2                 1        0                   1
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# ...

# %%
# Visualizing the last 10 rows of the data
data.tail(10)
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 356         2        2                 2        2                   2
# 357         2        2                 2        0                   1
# 358         2        3                 2        1                   0
# 359         2        2                 0        0                   0
# 360         2        2                 1        1                   0
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 356                  0                   0                         0
# ...

# %%
# Checking the column names of the data
data.columns
# Out:
# Index(['erythema', 'scaling', 'definite_borders', 'itching',
#        'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
#        'oral_mucosal_involvement', 'knee_and_elbow_involvement',
#        'scalp_involvement', 'family_history', 'melanin_incontinence',
#        'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
#        'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
#        'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
#        'elongation_of_the_rete_ridges',
#        'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
#        'munro_microabcess', 'focal_hypergranulosis',
#        'disappearance_of_the_granular_layer',
#        'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
#        'saw-tooth_appearance_of_retes', 'follicular_horn_plug',
#        'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
#        'band-like_infiltrate', 'Age', 'class'],
#       dtype='object')

# %%
# Checking the index of the data
data.index
# Out:
# RangeIndex(start=0, stop=366, step=1)

# %%
# Checking the number of rows and columns of the data
data.shape
# Out:
# (366, 35)

# %%
# Checking the basic information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   erythema                                  366 non-null    int64
#  1   scaling                                   366 non-null    int64
#  2   definite_borders                          366 non-null    int64
#  3   itching                                   366 non-null    int64
#  4   koebner_phenomenon                        366 non-null    int64
#  5   polygonal_papules                         366 non-null    int64
#  6   follicular_papules                        366 non-null    int64
#  7   oral_mucosal_involvement                  366 non-null    int64
#  8   knee_and_elbow_involvement                366 non-null    int64
#  9   scalp_involvement                         366 non-null    int64
# ...

# %%
# Checking the statistical information of the numerical column in the data
data.describe()
# Out:
#          erythema     scaling  definite_borders     itching  \
# count  366.000000  366.000000        366.000000  366.000000
# mean     2.068306    1.795082          1.549180    1.366120
# std      0.664753    0.701527          0.907525    1.138299
# min      0.000000    0.000000          0.000000    0.000000
# 25%      2.000000    1.000000          1.000000    0.000000
# 50%      2.000000    2.000000          2.000000    1.000000
# 75%      2.000000    2.000000          2.000000    2.000000
# max      3.000000    3.000000          3.000000    3.000000
#
#        koebner_phenomenon  polygonal_papules  follicular_papules  \
# count          366.000000         366.000000          366.000000
# mean             0.633880           0.448087            0.166667
# std              0.908016           0.957327            0.570588
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# ...

# %%
# Checking the statistical information of the categorical column in the data
data.describe(include="O")
# Out:
#         Age
# count   366
# unique   61
# top      40
# freq     17

# %%
# Checking the unique values for all the columns in the data
for i in data.columns:
    print(f"                                {i.title()}                        ")
    print("\n")
    print(f"* The number of unique values in {i} column :",data[i].nunique())
    print(">>",data[i].unique())
    print('==============================================================================')
    print("\n")
# Out:
#                                 Erythema
#
#
# * The number of unique values in erythema column : 4
# >> [2 3 1 0]
# ...
#
#
#                                 Scaling
#
#
# * The number of unique values in scaling column : 4
# >> [2 3 1 0]
# ...
#
#
#                                 Definite_Borders
#
#
# * The number of unique values in definite_borders column : 4
# >> [0 3 2 1]
# ...
#
#
#                                 Itching
#
#
# * The number of unique values in itching column : 4
# >> [3 2 0 1]
# ...
#
#
#                                 Koebner_Phenomenon
#
#
# * The number of unique values in koebner_phenomenon column : 4
# >> [0 1 2 3]
# ...
#
#
#                                 Polygonal_Papules
#
#
# * The number of unique values in polygonal_papules column : 4
# >> [0 3 2 1]
# ...
#
#
#                                 Follicular_Papules
#
#
# * The number of unique values in follicular_papules column : 4
# >> [0 3 1 2]
# ...
#
#
#                                 Oral_Mucosal_Involvement
#
#
# ...

# %%
# Checking the value_counts 
for i in data.columns:
    print(data[i].value_counts())
    print('============================')
    print("\n")
# Out:
# erythema
# 2    215
# 3     90
# 1     57
# 0      4
# Name: count, dtype: int64
# ...
#
#
# scaling
# 2    195
# 1    111
# 3     52
# 0      8
# Name: count, dtype: int64
# ...
#
#
# definite_borders
# 2    168
# 1     93
# 0     59
# 3     46
# Name: count, dtype: int64
# ...
#
#
# itching
# 0    118
# 2    100
# 3     76
# 1     72
# Name: count, dtype: int64
# ...
#
#
# koebner_phenomenon
# 0    224
# 1     70
# 2     54
# 3     18
# Name: count, dtype: int64
# ...
#
#
# polygonal_papules
# 0    297
# 2     41
# 3     27
# 1      1
# Name: count, dtype: int64
# ...
#
#
# follicular_papules
# 0    333
# 2     16
# 1     11
# 3      6
# Name: count, dtype: int64
# ...
#
#
# oral_mucosal_involvement
# 0    299
# 2     45
# 3     13
# 1      9
# Name: count, dtype: int64
# ...
#
#
# knee_and_elbow_involvement
# 0    251
# 2     64
# 1     28
# 3     23
# Name: count, dtype: int64
# ...
#
#
# scalp_involvement
# 0    264
# 2     56
# 1     30
# 3     16
# Name: count, dtype: int64
# ...
#
#
# family_history
# 0    320
# 1     46
# ...

# %% [markdown]
# ## 4. CHECKING CORRUPTED VALUES

# %%
data[data.Age=='?']
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 33          2        2                 1        0                   0
# 34          2        1                 0        0                   2
# 35          2        2                 1        2                   0
# 36          2        1                 2        3                   2
# 262         2        1                 0        2                   0
# 263         1        1                 1        3                   0
# 264         1        1                 0        2                   0
# 265         1        1                 0        3                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 33                   0                   0                         0
# 34                   0                   0                         0
# 35                   0                   0                         0
# ...

# %%
data['Age']=data['Age'].replace('?',data['Age'].mode()[0])

# %%
# Verification
data.Age.unique()
# Out:
# array(['55', '8', '26', '40', '45', '41', '18', '57', '22', '30', '20',
#        '21', '10', '65', '38', '23', '17', '51', '42', '44', '33', '43',
#        '50', '34', '15', '46', '62', '35', '48', '12', '52', '60', '32',
#        '19', '29', '25', '36', '13', '27', '31', '28', '64', '39', '47',
#        '16', '0', '7', '70', '37', '61', '67', '56', '53', '24', '58',
#        '49', '63', '68', '9', '75'], dtype=object)

# %%
# convert Object dtype to Int dtype
data['Age']=data['Age'].astype(int)

# %%
# Verification
data.Age.dtype
# Out:
# dtype('int32')

# %% [markdown]
# ## 5. EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# ### 5.1. PROFILE REPORT

# %%
report = ProfileReport(data, title="EDA",explorative=False)
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.12.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-03-18 18:13:55.978452&quot;&gt;&lt;title&gt;EDA&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %% [markdown]
# ### 5.2. UNIVARIATE ANALYSIS FOR NUMERICAL COLUMNS

# %%
plt.figure(figsize=(40,30),facecolor='green')
plotnumber=1
for i in data.columns:
    if plotnumber<=35:
        ax=plt.subplot(5,7,plotnumber)
        sns.histplot(data[i],kde=True)
        plt.xlabel(i,fontsize=20)
        plt.ylabel('count',fontsize=20)
    plotnumber=plotnumber+1

plt.tight_layout()

# %% [markdown]
# ### 5.3. BIVARIATE ANALYSIS

# %%
# Erythema vs Itching
plt.figure(figsize=(4,3))
sns.barplot(data,x="erythema",y="itching",palette="Set1")
plt.show()
a=data[(data.erythema==3)&(data.itching==3)]
b=data[(data.erythema==2)&(data.itching==2)]
print(f'--> Patients who present with severe erythema and itching : {len(a)}\n')
print(f'--> Patients who present with moderate erythema and itching : {len(b)}\n')
print(f'--> These patients should be treated first because they have severe symptoms that require immediate attention.')
# Out:
# --> Patients who present with severe erythema and itching : 14
#
# --> Patients who present with moderate erythema and itching : 58
#
# --> These patients should be treated first because they have severe symptoms that require immediate attention.

# %%
# Age vs Scaling
plt.figure(figsize=(4,3))
sns.scatterplot(data,x="Age",y="scaling")
plt.show()

# %% [markdown]
# ##### --> Scaling levels (0, 1, 2, 3) are evenly distributed across different ages, indicating that age is not a strong determinant of scaling severity.
# ##### --> More severe scaling (levels 2 and 3) is frequent across all ages.
# ##### --> There are some individuals in older age groups with no scaling, but they are fewer.

# %%
# Class vs Family History 
plt.figure(figsize=(4,3))
sns.barplot(data,x="class",y="family_history",palette="husl")
plt.show()
print(f'--> Genetic factors significantly contribute to Pityriasis Rubra Pilaris(6) and Psoriasis(1).')
# Out:
# --> Genetic factors significantly contribute to Pityriasis Rubra Pilaris(6) and Psoriasis(1).

# %%
# Knee and Elbow Involvement vs. Acanthosis
plt.figure(figsize=(6,3))
sns.barplot(x='acanthosis',y='knee_and_elbow_involvement',hue='class',palette='Set1',data=data)
plt.show()
print(f'--> Patients who have acanthosis are typically found in psoriasis(1) and Pityriasis Rubra Pilaris(6),that often affects knees and elbows.')
# Out:
# --> Patients who have acanthosis are typically found in psoriasis(1) and Pityriasis Rubra Pilaris(6),that often affects knees and elbows.

# %%
# Munro Microabscess vs Scalp Involvement 
plt.figure(figsize=(6,3))
sns.barplot(data=data,x="munro_microabcess",y="scalp_involvement",hue='class',palette="Set1")
plt.show()
c=data[(data.munro_microabcess)&(data.scalp_involvement)&(data['class']==1)]
print(f'--> Patients who have Munro microabscesses are typically found in psoriasis(1),that commonly affects the scalp: {len(c)}')
# Out:
# --> Patients who have Munro microabscesses are typically found in psoriasis(1),that commonly affects the scalp: 24

# %%
# Saw-Tooth Appearance vs Band-like Infiltrate
plt.figure(figsize=(6,3))
sns.barplot(data,x="saw-tooth_appearance_of_retes",y="band-like_infiltrate",hue='class',palette="husl")
plt.show()
d=data[(data['saw-tooth_appearance_of_retes'])&(data['band-like_infiltrate'])&(data['class']==3)]
print(f'--> Patients who have saw-tooth pattern with a band-like infiltrate are typically found in lichen planus(3): {len(d)}')
# Out:
# --> Patients who have saw-tooth pattern with a band-like infiltrate are typically found in lichen planus(3): 22

# %%
# Parakeratosis vs Spongiform Pustule
plt.figure(figsize=(6,3))
sns.barplot(data,x="parakeratosis",y="spongiform_pustule",hue='class',palette="Set1")
plt.show()
e=data[(data['parakeratosis'])&(data['spongiform_pustule'])&(data['class']==1)]
print(f'--> Patients who have parakeratosis with a spongiform_pustule are typically found in psoriasis(1): {len(e)}')
# Out:
# --> Patients who have parakeratosis with a spongiform_pustule are typically found in psoriasis(1): 16

# %% [markdown]
# ### 4.4. MULTIVARIATE ANALYSIS

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# ## 5. DATA PREPROCESSING

# %% [markdown]
# ### 5.1. CHECKING NULL VALUES

# %%
print(data.isnull().sum())
print('\n')
print(f'--> No Null Values Present')
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# PNL_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %% [markdown]
# ### 5.2. CHECKING DUPLICATE VALUES

# %%
print(data.duplicated().sum())
print('\n')
print(f'--> No Duplicate Values Present')
# Out:
# 0
#
#
# --> No Duplicate Values Present

# %% [markdown]
# ### 5.3. SCALING FOR NUMERICAL COLUMNS

# %% [markdown]
# #### 5.3.1. Using StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
df=StandardScaler().fit_transform(data.iloc[:,:-1])
df
# Out:
# array([[-0.1028946 ,  0.29250271, -1.70937509, ..., -1.19445878,
#         -0.50221531,  1.22967154],
#        [ 1.40348234,  1.71991595,  1.60084334, ..., -1.19445878,
#         -0.50221531, -1.87373365],
#        [-0.1028946 , -1.13491053,  0.49743719, ...,  0.18463243,
#          2.2142005 , -0.6851955 ],
#        ...,
#        [ 1.40348234,  0.29250271,  0.49743719, ...,  0.18463243,
#          2.2142005 , -0.5531357 ],
#        [-0.1028946 , -1.13491053,  1.60084334, ...,  0.18463243,
#          2.2142005 ,  0.89952205],
#        [ 1.40348234,  0.29250271,  0.49743719, ...,  1.56372365,
#         -0.50221531, -0.09092642]])

# %% [markdown]
# ### 6. DATA SPLITTING

# %%
x = pd.DataFrame(df,columns=data.columns[:-1]) # Independent variables
x
# Out:
#      erythema   scaling  definite_borders   itching  koebner_phenomenon  \
# 0   -0.102895  0.292503         -1.709375  1.437334           -0.699049
# 1    1.403482  1.719916          1.600843  0.557628            0.403761
# 2   -0.102895 -1.134911          0.497437  1.437334            0.403761
# 3   -0.102895  0.292503          0.497437 -1.201784           -0.699049
# 4   -0.102895  1.719916          0.497437  0.557628            1.506571
# ..        ...       ...               ...       ...                 ...
# 361 -0.102895 -1.134911         -0.605969 -1.201784            0.403761
# 362  1.403482  0.292503         -0.605969 -1.201784            0.403761
# 363  1.403482  0.292503          0.497437  0.557628            2.609381
# 364 -0.102895 -1.134911          1.600843 -0.322078            1.506571
# 365  1.403482  0.292503          0.497437 -1.201784           -0.699049
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %%
y=data['class'] # Dependent variable
y
# Out:
# 0      2
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 361    4
# 362    4
# 363    3
# 364    3
# 365    1
# Name: class, Length: 366, dtype: int64

# %% [markdown]
# ### 6.1. train_test_split for splitting the data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (274, 34)
# (92, 34)
# (274,)
# (92,)

# %%
# Initializing SMOTE
from imblearn.over_sampling import SMOTE
smote= SMOTE(random_state=42)

# fitting and resampling training data
x_train_smote,y_train_smote=smote.fit_resample(x_train,y_train)

# %% [markdown]
# ### 6.2. FEATURE EXTRACTION

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=0.95)
pca_x_train=pca.fit_transform(x_train_smote)
pca_x_test=pca.transform(x_test)
print(pca_x_train.shape)
print(pca_x_test.shape)
# Out:
# (468, 20)
# (92, 20)

# %% [markdown]
# ### Justification for applying PCA method(Feature Extraction):
# #### --> Applying PCA to remove redundant features is that it reduces multicollinearity by transforming correlated features into a new set of orthogonal (uncorrelated) principal components, thereby simplifying the data and improving model interpretability and performance.

# %% [markdown]
# ## 7. MODEL CREATION

# %% [markdown]
# ### 7.1. LOGISTIC REGRESSION

# %%
log_model=LogisticRegression(multi_class='multinomial')
log_model.fit(pca_x_train,y_train_smote)
y_pred=log_model.predict(pca_x_test)
print(f' log_accuracy_score :{accuracy_score(y_test,y_pred)}\n')
print(f' log_confusion_matrix :{confusion_matrix(y_test,y_pred)}\n')
print(f' log_classification_report :{classification_report(y_test,y_pred)}')
log_accuracy=accuracy_score(y_test,y_pred)
# Out:
#  log_accuracy_score :0.9782608695652174
#
#  log_confusion_matrix :[[34  0  0  0  0  0]
#  [ 0 12  0  0  0  0]
#  [ 0  0 17  0  0  0]
#  [ 0  2  0  9  0  0]
#  [ 0  0  0  0 14  0]
#  [ 0  0  0  0  0  4]]
#
#  log_classification_report :              precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        34
#            2       0.86      1.00      0.92        12
#            3       1.00      1.00      1.00        17
#            4       1.00      0.82      0.90        11
#            5       1.00      1.00      1.00        14
#            6       1.00      1.00      1.00         4
#
#     accuracy                           0.98        92
#    macro avg       0.98      0.97      0.97        92
# weighted avg       0.98      0.98      0.98        92

# %% [markdown]
# #### CHECK OVERFITTING

# %%
from sklearn.model_selection import cross_val_score
cv_scores=cross_val_score(log_model,pca_x_train,y_train_smote,cv=5)
print(f"Cross-validation Accuracy: {cv_scores.mean():.4f}, Cross-validation Std Dev: {cv_scores.std():.4f}")
# Out:
# Cross-validation Accuracy: 0.9766, Cross-validation Std Dev: 0.0237

# %% [markdown]
# ### 7.2. DECISION TREE

# %%
dt_model=DecisionTreeClassifier()
dt_model.fit(pca_x_train,y_train_smote)
y_pred=dt_model.predict(pca_x_test)
print(f' dt_accuracy_score :{accuracy_score(y_test,y_pred)}\n')
print(f' dt_confusion_matrix :{confusion_matrix(y_test,y_pred)}\n')
print(f' dt_classification_report :{classification_report(y_test,y_pred)}')
dt_accuracy=accuracy_score(y_test,y_pred)
# Out:
#  dt_accuracy_score :0.9891304347826086
#
#  dt_confusion_matrix :[[34  0  0  0  0  0]
#  [ 0 12  0  0  0  0]
#  [ 0  0 17  0  0  0]
#  [ 0  1  0 10  0  0]
#  [ 0  0  0  0 14  0]
#  [ 0  0  0  0  0  4]]
#
#  dt_classification_report :              precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        34
#            2       0.92      1.00      0.96        12
#            3       1.00      1.00      1.00        17
#            4       1.00      0.91      0.95        11
#            5       1.00      1.00      1.00        14
#            6       1.00      1.00      1.00         4
#
#     accuracy                           0.99        92
#    macro avg       0.99      0.98      0.99        92
# weighted avg       0.99      0.99      0.99        92

# %%
cv_scores=cross_val_score(dt_model,pca_x_train,y_train_smote,cv=5)
print(f"Cross-validation Accuracy: {cv_scores.mean():.4f}, Cross-validation Std Dev: {cv_scores.std():.4f}")
# Out:
# Cross-validation Accuracy: 0.9596, Cross-validation Std Dev: 0.0296

# %% [markdown]
# ### 7.3. RANDOM FOREST

# %%
rf_model=RandomForestClassifier()
rf_model.fit(pca_x_train,y_train_smote)
y_pred=rf_model.predict(pca_x_test)
print(f' rf_accuracy_score :{accuracy_score(y_test,y_pred)}\n')
print(f' rf_confusion_matrix :{confusion_matrix(y_test,y_pred)}\n')
print(f' rf_classification_report :{classification_report(y_test,y_pred)}')
rf_accuracy=accuracy_score(y_test,y_pred)
# Out:
#  rf_accuracy_score :0.9782608695652174
#
#  rf_confusion_matrix :[[34  0  0  0  0  0]
#  [ 0 12  0  0  0  0]
#  [ 0  0 17  0  0  0]
#  [ 0  2  0  9  0  0]
#  [ 0  0  0  0 14  0]
#  [ 0  0  0  0  0  4]]
#
#  rf_classification_report :              precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        34
#            2       0.86      1.00      0.92        12
#            3       1.00      1.00      1.00        17
#            4       1.00      0.82      0.90        11
#            5       1.00      1.00      1.00        14
#            6       1.00      1.00      1.00         4
#
#     accuracy                           0.98        92
#    macro avg       0.98      0.97      0.97        92
# weighted avg       0.98      0.98      0.98        92

# %%
cv_scores=cross_val_score(rf_model,pca_x_train,y_train_smote,cv=5)
print(f"Cross-validation Accuracy: {cv_scores.mean():.4f}, Cross-validation Std Dev: {cv_scores.std():.4f}")
# Out:
# Cross-validation Accuracy: 0.9872, Cross-validation Std Dev: 0.0156

# %% [markdown]
# ### 7.4. GRADIENT BOOSTING

# %%
gb_model=GradientBoostingClassifier()
gb_model.fit(pca_x_train,y_train_smote)
y_pred=gb_model.predict(pca_x_test)
print(f' gb_accuracy_score :{accuracy_score(y_test,y_pred)}\n')
print(f' gb_confusion_matrix :{confusion_matrix(y_test,y_pred)}\n')
print(f' gb_classification_report :{classification_report(y_test,y_pred)}')
gb_accuracy=accuracy_score(y_test,y_pred)
# Out:
#  gb_accuracy_score :0.9347826086956522
#
#  gb_confusion_matrix :[[32  1  0  1  0  0]
#  [ 0 12  0  0  0  0]
#  [ 0  0 17  0  0  0]
#  [ 0  3  0  8  0  0]
#  [ 0  0  0  1 13  0]
#  [ 0  0  0  0  0  4]]
#
#  gb_classification_report :              precision    recall  f1-score   support
#
#            1       1.00      0.94      0.97        34
#            2       0.75      1.00      0.86        12
#            3       1.00      1.00      1.00        17
#            4       0.80      0.73      0.76        11
#            5       1.00      0.93      0.96        14
#            6       1.00      1.00      1.00         4
#
#     accuracy                           0.93        92
#    macro avg       0.92      0.93      0.93        92
# weighted avg       0.94      0.93      0.94        92

# %%
cv_scores=cross_val_score(gb_model,pca_x_train,y_train_smote,cv=5)
print(f"Cross-validation Accuracy: {cv_scores.mean():.4f}, Cross-validation Std Dev: {cv_scores.std():.4f}")
# Out:
# Cross-validation Accuracy: 0.9766, Cross-validation Std Dev: 0.0217

# %% [markdown]
# ### 7.5. KNN

# %%
knn_model=KNeighborsClassifier()
knn_model.fit(pca_x_train,y_train_smote)
y_pred=knn_model.predict(pca_x_test)
print(f' knn_accuracy_score :{accuracy_score(y_test,y_pred)}\n')
print(f' knn_confusion_matrix :{confusion_matrix(y_test,y_pred)}\n')
print(f' knn_classification_report :{classification_report(y_test,y_pred)}')
knn_accuracy=accuracy_score(y_test,y_pred)
# Out:
#  knn_accuracy_score :0.967391304347826
#
#  knn_confusion_matrix :[[32  1  0  0  1  0]
#  [ 0 12  0  0  0  0]
#  [ 0  0 17  0  0  0]
#  [ 0  1  0 10  0  0]
#  [ 0  0  0  0 14  0]
#  [ 0  0  0  0  0  4]]
#
#  knn_classification_report :              precision    recall  f1-score   support
#
#            1       1.00      0.94      0.97        34
#            2       0.86      1.00      0.92        12
#            3       1.00      1.00      1.00        17
#            4       1.00      0.91      0.95        11
#            5       0.93      1.00      0.97        14
#            6       1.00      1.00      1.00         4
#
#     accuracy                           0.97        92
#    macro avg       0.97      0.98      0.97        92
# weighted avg       0.97      0.97      0.97        92

# %%
cv_scores=cross_val_score(knn_model,pca_x_train,y_train_smote,cv=5)
print(f"Cross-validation Accuracy: {cv_scores.mean():.4f}, Cross-validation Std Dev: {cv_scores.std():.4f}")
# Out:
# Cross-validation Accuracy: 0.9616, Cross-validation Std Dev: 0.0185

# %% [markdown]
# ### 7.6. ARTIFICIAL NEURAL NETWORKS

# %%
ann_model=MLPClassifier()
ann_model.fit(pca_x_train,y_train_smote)
y_pred=ann_model.predict(pca_x_test)
print(f' ann_accuracy_score :{accuracy_score(y_test,y_pred)}\n')
print(f' ann_confusion_matrix :{confusion_matrix(y_test,y_pred)}\n')
print(f' ann_classification_report :{classification_report(y_test,y_pred)}')
ann_accuracy=accuracy_score(y_test,y_pred)
# Out:
#  ann_accuracy_score :0.9782608695652174
#
#  ann_confusion_matrix :[[34  0  0  0  0  0]
#  [ 0 12  0  0  0  0]
#  [ 0  0 17  0  0  0]
#  [ 0  2  0  9  0  0]
#  [ 0  0  0  0 14  0]
#  [ 0  0  0  0  0  4]]
#
#  ann_classification_report :              precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        34
#            2       0.86      1.00      0.92        12
#            3       1.00      1.00      1.00        17
#            4       1.00      0.82      0.90        11
#            5       1.00      1.00      1.00        14
#            6       1.00      1.00      1.00         4
#
#     accuracy                           0.98        92
#    macro avg       0.98      0.97      0.97        92
# weighted avg       0.98      0.98      0.98        92

# %%
cv_scores=cross_val_score(ann_model,pca_x_train,y_train_smote,cv=5)
print(f"Cross-validation Accuracy: {cv_scores.mean():.4f}, Cross-validation Std Dev: {cv_scores.std():.4f}")
# Out:
# Cross-validation Accuracy: 0.9723, Cross-validation Std Dev: 0.0282

# %% [markdown]
# ### 7.7. SUPPORT VECTOR MACHINE

# %%
svm_model=SVC()
svm_model.fit(pca_x_train,y_train_smote)
y_pred=svm_model.predict(pca_x_test)
print(f' svm_accuracy_score :{accuracy_score(y_test,y_pred)}\n')
print(f' svm_confusion_matrix :{confusion_matrix(y_test,y_pred)}\n')
print(f' svm_classification_report :{classification_report(y_test,y_pred)}')
svm_accuracy=accuracy_score(y_test,y_pred)
# Out:
#  svm_accuracy_score :0.9782608695652174
#
#  svm_confusion_matrix :[[34  0  0  0  0  0]
#  [ 0 12  0  0  0  0]
#  [ 0  0 17  0  0  0]
#  [ 0  2  0  9  0  0]
#  [ 0  0  0  0 14  0]
#  [ 0  0  0  0  0  4]]
#
#  svm_classification_report :              precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        34
#            2       0.86      1.00      0.92        12
#            3       1.00      1.00      1.00        17
#            4       1.00      0.82      0.90        11
#            5       1.00      1.00      1.00        14
#            6       1.00      1.00      1.00         4
#
#     accuracy                           0.98        92
#    macro avg       0.98      0.97      0.97        92
# weighted avg       0.98      0.98      0.98        92

# %%
cv_scores=cross_val_score(svm_model,pca_x_train,y_train_smote,cv=5)
print(f"Cross-validation Accuracy: {cv_scores.mean():.4f}, Cross-validation Std Dev: {cv_scores.std():.4f}")
# Out:
# Cross-validation Accuracy: 0.9809, Cross-validation Std Dev: 0.0237

# %% [markdown]
# ## 8. MODEL COMPARISON REPORT

# %%
# Creating a dictionary for models and their accuracy scores
comparison_dict = {'Model': ['LogisticRegression','DecisionTreeClassifier','RandomForestClassifier','GradientBoostingClassifier','KNeighborsClassifier','MLPClassifier','SVC'],
                   'accuracy_score': [log_accuracy,dt_accuracy,rf_accuracy,gb_accuracy,knn_accuracy,ann_accuracy,svm_accuracy]}

# Creating DataFrame
comparison_df = pd.DataFrame(comparison_dict)
print(comparison_df.to_string(index=False))
# Out:
#                      Model  accuracy_score
#         LogisticRegression        0.978261
#     DecisionTreeClassifier        0.989130
#     RandomForestClassifier        0.978261
# GradientBoostingClassifier        0.934783
#       KNeighborsClassifier        0.967391
#              MLPClassifier        0.978261
#                        SVC        0.978261

# %%
# Visualization
comparison_df = comparison_df.sort_values(by='accuracy_score', ascending=True)

max_index = comparison_df['accuracy_score'].idxmax()  # This returns the row index having highest accuracy_score

plt.figure(figsize=(16, 5))
sns.lineplot(data=comparison_df, x='Model', y='accuracy_score', marker='o', color='blue', label="Model Performance")

plt.scatter(comparison_df.loc[max_index, 'Model'], comparison_df.loc[max_index, 'accuracy_score'],color='red', s=100, label="Best Model")

plt.xlabel("Model")
plt.ylabel("accuracy_score")
plt.legend()
plt.title("Comparison of Model Performance (accuracy_score)")
plt.show()

# %% [markdown]
# ## 9. CONCLUSION

# %% [markdown]
# #### --> For this specific dataset and task, the 𝗗𝗲𝗰𝗶𝘀𝗶𝗼𝗻𝗧𝗿𝗲𝗲𝗖𝗹𝗮𝘀𝘀𝗶𝗳𝗶𝗲𝗿 is the most effective model. Its superior accuracy(99%) suggests it captures the underlying patterns in the data most accurately.
#
# #### --> Overall, the DecisionTreeClassifier has the ability to balance interpretability, robustness, and efficiency, making it a versatile and effective choice for many classification tasks.
#
# #### --> Even models such as LogisticRegression, MLPClassifier, RandomForestClassifier and SVC almost gives similar accuracy(98%) which works well with this classification problem.

# %% [markdown]
# # <center><font color="red">Important to note:</center>
# ## 1) Justifications for Not Applying Outlier Handling:
# #### --> Since most features in the dataset are numerical and range between 0 to 3, applying the IQR method for outlier handling is not suitable. The IQR method typically identifies values beyond 1.5 times the interquartile range as outliers, which in this case incorrectly treats the value 3 as an outlier, leading to its removal and introducing NaNs.
# #### --> Given this limited feature range, the dataset inherently lacks extreme outliers, making outlier handling unnecessary.
#
# ## 2) Justifications for Not Applying Hyperparameter Tuning:
# #### --> Since test accuracy is consistently high (i.e., between 97-98%) across multiple algorithms.
# #### --> Confusion matrix shows minimal misclassification across all classes.
# #### --> Stable cross-validation scores across different models indicate No Overfitting present.

# %% [markdown]
# ## 10. CHALLENGES FACED
# #### 1. Extracting insights from EDA.
# #### 2. Ensuring that models are fair and unbiased.
# #### 3. Check for overfitting.
# #### 4. Took slightly more computational time.

# %% [markdown]
# ## PROJECT DETAILS:
# ##### Project Team ID : PTID-CDS-JAN-25-2368
#
# ##### Project ID : PRCP-1027-Skin Disorder
#
# ##### Team Members:
#
# ##### 1. Adithya E - ecadithya12@gmail.com
# ##### 2. Peraisoodan Viswanath S - peraisoodanviswanath.s@gmail.com
# ##### 3. Nirmal Newton M - nirmalnewton2003@gmail.com
# ##### 4. Sivadhasan K - sivadhasansd@gmail.com
